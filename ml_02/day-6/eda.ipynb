# %%
import pandas as pd

df = pd.DataFrame({
    "city": ["New York", "Los Angeles", "Chicago", "Houston", "Phoenix"],
    "population": [8419000, 3980000, 2716000, 2328000, 1690000] 
})

print(df['city'].describe())
print(df['population'].describe())


df.head(3)
df.tail(2)
df.info()
df.describe()  
df.sample(3) 
print(df.shape)
# Out:
# count            5
# unique           5
# top       New York
# freq             1
# Name: city, dtype: object
# count    5.000000e+00
# mean     3.826600e+06
# std      2.699906e+06
# min      1.690000e+06
# 25%      2.328000e+06
# 50%      2.716000e+06
# 75%      3.980000e+06
# max      8.419000e+06
# Name: population, dtype: float64
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   city        5 non-null      str
#  1   population  5 non-null      int64
# dtypes: int64(1), str(1)
# memory usage: 212.0 bytes
# (5, 2)

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({
    "EmpID": [101, 102, 103, 104, 105],
    "Name": ["Alice", "Bob", "Charlie", "David", "Eve"],
    "Department": ["HR", "IT", "Finance", "IT", "HR"],
    "age": [25, 30, 35, 40, 45],
    "Salary": [50000, 60000, 70000, 80000, 90000],
    "experience": [2, 5, 10, 15, 20]
})
print(df)


df.head(3)
df.tail(2)
df.info()
df.describe()  
df.sample(3) 
print(df.shape)
# Out:
#    EmpID     Name Department  age  Salary  experience
# 0    101    Alice         HR   25   50000           2
# 1    102      Bob         IT   30   60000           5
# 2    103  Charlie    Finance   35   70000          10
# 3    104    David         IT   40   80000          15
# 4    105      Eve         HR   45   90000          20
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   EmpID       5 non-null      int64
#  1   Name        5 non-null      str
#  2   Department  5 non-null      str
#  3   age         5 non-null      int64
#  4   Salary      5 non-null      int64
#  5   experience  5 non-null      int64
# dtypes: int64(4), str(2)
# memory usage: 372.0 bytes
# (5, 6)
