# %% [markdown]
# # 📊 EduTrack — NumPy Performance Report
#
# **Day 3 · NumPy Fundamentals — Mini Challenge**
#
# You are a junior data analyst at *EduTrack*. The academics team gives you the final exam scores of 10 students and asks for a quick performance report using NumPy.
#
# Scores: `78, 92, 56, 88, 95, 43, 67, 81, 73, 60`

# %% [markdown]
# ## 1. Import NumPy and store the scores

# %%
import numpy as np

scores = np.array([78, 92, 56, 88, 95, 43, 67, 81, 73, 60])
print("Scores:", scores)
# Out:
# Scores: [78 92 56 88 95 43 67 81 73 60]

# %% [markdown]
# ## 2. Total, average, highest, and lowest

# %%
print("Total:", np.sum(scores))
print("Average:", np.mean(scores))
print("Highest:", np.max(scores))
print("Lowest:", np.min(scores))
# Out:
# Total: 733
# Average: 73.3
# Highest: 95
# Lowest: 43

# %% [markdown]
# ## 3. Median and standard deviation

# %%
print("Median:", np.median(scores))
print("Standard Deviation:", round(np.std(scores), 1))
# Out:
# Median: 75.5
# Standard Deviation: 16.0

# %% [markdown]
# ## 4. Position of the top scorer (`argmax`)

# %%
print("Top scorer is at index:", np.argmax(scores))
# Out:
# Top scorer is at index: 4

# %% [markdown]
# ## 5 & 6. Boolean indexing — who passed (score ≥ 60) and how many

# %%
passed = scores[scores >= 60]
print("Passed students (>=60):", passed)
print("Number of students who passed:", passed.size)
# Out:
# Passed students (>=60): [78 92 88 95 67 81 73 60]
# Number of students who passed: 8

# %% [markdown]
# ## 7. Vectorized operation — add 5 grace marks to every score

# %%
grace = scores + 5
print("Scores after 5 grace marks:", grace)
# Out:
# Scores after 5 grace marks: [ 83  97  61  93 100  48  72  86  78  65]

# %% [markdown]
# ## 🌟 Stretch Goals
#
# - Pass percentage
# - Position of the lowest scorer (`argmin`)
# - Cap grace-mark scores at 100 (`np.clip`)

# %%
pass_percentage = passed.size / scores.size * 100
print("Pass percentage:", pass_percentage, "%")

print("Lowest scorer is at index:", np.argmin(scores))

grace_capped = np.clip(scores + 5, None, 100)
print("Grace marks capped at 100:", grace_capped)
# Out:
# Pass percentage: 80.0 %
# Lowest scorer is at index: 5
# Grace marks capped at 100: [ 83  97  61  93 100  48  72  86  78  65]
